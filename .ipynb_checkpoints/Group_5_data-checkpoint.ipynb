# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Group_5_data.csv")
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(C)  Humidity(%)  \
# 0  01/12/2017                254     0            -5.2           37
# 1  01/12/2017                204     1            -5.5           38
# 2  01/12/2017                173     2            -6.0           39
# 3  01/12/2017                107     3            -6.2           40
# 4  01/12/2017                 78     4            -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# 0               2.2              2000                     -17.6
# 1               0.8              2000                     -17.6
# 2               1.0              2000                     -17.7
# 3               0.9              2000                     -17.6
# 4               2.3              2000                     -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm) Seasons     Holiday  \
# 0                      0.0           0.0            0.0  Winter  No Holiday
# 1                      0.0           0.0            0.0  Winter  No Holiday
# 2                      0.0           0.0            0.0  Winter  No Holiday
# 3                      0.0           0.0            0.0  Winter  No Holiday
# 4                      0.0           0.0            0.0  Winter  No Holiday
#
#   Functioning Day
# 0             Yes
# 1             Yes
# 2             Yes
# 3             Yes
# 4             Yes

# %%
df.describe()
# Out:
#        Rented Bike Count         Hour  Temperature(C)  Humidity(%)  \
# count        8760.000000  8760.000000     8760.000000  8760.000000
# mean          704.602055    11.500000       12.882922    58.226256
# std           644.997468     6.922582       11.944825    20.362413
# min             0.000000     0.000000      -17.800000     0.000000
# 25%           191.000000     5.750000        3.500000    42.000000
# 50%           504.500000    11.500000       13.700000    57.000000
# 75%          1065.250000    17.250000       22.500000    74.000000
# max          3556.000000    23.000000       39.400000    98.000000
#
#        Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# count       8760.000000       8760.000000               8760.000000
# mean           1.724909       1436.825799                  4.073813
# std            1.036300        608.298712                 13.060369
# min            0.000000         27.000000                -30.600000
# 25%            0.900000        940.000000                 -4.700000
# 50%            1.500000       1698.000000                  5.100000
# 75%            2.300000       2000.000000                 14.800000
# max            7.400000       2000.000000                 27.200000
#
#        Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)
# count              8760.000000   8760.000000    8760.000000
# mean                  0.569111      0.148687       0.075068
# std                   0.868746      1.128193       0.436746
# min                   0.000000      0.000000       0.000000
# 25%                   0.000000      0.000000       0.000000
# 50%                   0.010000      0.000000       0.000000
# 75%                   0.930000      0.000000       0.000000
# max                   3.520000     35.000000       8.800000

# %%
# Gives us the no of cells with NA in each column

df.isna().sum()
# Out:
# Date                        0
# Rented Bike Count           0
# Hour                        0
# Temperature(C)              0
# Humidity(%)                 0
# Wind speed (m/s)            0
# Visibility (10m)            0
# Dew point temperature(C)    0
# Solar Radiation (MJ/m2)     0
# Rainfall(mm)                0
# Snowfall (cm)               0
# Seasons                     0
# Holiday                     0
# Functioning Day             0
# dtype: int64

# %%
# Its easier to work with numarical data then strings (int, float, bool)

df.dtypes
# Out:
# Date                         object
# Rented Bike Count             int64
# Hour                          int64
# Temperature(C)              float64
# Humidity(%)                   int64
# Wind speed (m/s)            float64
# Visibility (10m)              int64
# Dew point temperature(C)    float64
# Solar Radiation (MJ/m2)     float64
# Rainfall(mm)                float64
# Snowfall (cm)               float64
# Seasons                      object
# Holiday                      object
# Functioning Day              object
# dtype: object

# %%
# To know if its string type or catagorical data

df["Seasons"].nunique(), df["Seasons"].unique()
# Out:
# (4, array(['Winter', 'Spring', 'Summer', 'Autumn'], dtype=object))

# %%
# Converting Str to bool type using simple 1-hot encoding concept

df["is_Winter"] = df["Seasons"] == "Winter"
df["is_Spring"] = df["Seasons"] == "Spring"
df["is_Summer"] = df["Seasons"] == "Summer"
df["is_Autumn"] = df["Seasons"] == "Autumn"
df.drop("Seasons", inplace = True, axis = 1)
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(C)  Humidity(%)  \
# 0  01/12/2017                254     0            -5.2           37
# 1  01/12/2017                204     1            -5.5           38
# 2  01/12/2017                173     2            -6.0           39
# 3  01/12/2017                107     3            -6.2           40
# 4  01/12/2017                 78     4            -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# 0               2.2              2000                     -17.6
# 1               0.8              2000                     -17.6
# 2               1.0              2000                     -17.7
# 3               0.9              2000                     -17.6
# 4               2.3              2000                     -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)     Holiday  \
# 0                      0.0           0.0            0.0  No Holiday
# 1                      0.0           0.0            0.0  No Holiday
# 2                      0.0           0.0            0.0  No Holiday
# 3                      0.0           0.0            0.0  No Holiday
# 4                      0.0           0.0            0.0  No Holiday
#
#   Functioning Day  is_Winter  is_Spring  is_Summer  is_Autumn
# 0             Yes       True      False      False      False
# 1             Yes       True      False      False      False
# 2             Yes       True      False      False      False
# 3             Yes       True      False      False      False
# 4             Yes       True      False      False      False

# %%
df["Holiday"].nunique(), df["Holiday"].unique()
# Out:
# (2, array(['No Holiday', 'Holiday'], dtype=object))

# %%
df["Functioning Day"].nunique(), df["Functioning Day"].unique()
# Out:
# (2, array(['Yes', 'No'], dtype=object))

# %%
# Since we have only 2 catagories, can be encoded in just 1 column

df["is_Holiday"] = df["Holiday"] == "Holiday"
df["is_Functioning_day"] = df["Functioning Day"] == "Yes"
df.drop(["Holiday", "Functioning Day"], inplace = True, axis = 1)
df.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(C)  Humidity(%)  \
# 0  01/12/2017                254     0            -5.2           37
# 1  01/12/2017                204     1            -5.5           38
# 2  01/12/2017                173     2            -6.0           39
# 3  01/12/2017                107     3            -6.2           40
# 4  01/12/2017                 78     4            -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# 0               2.2              2000                     -17.6
# 1               0.8              2000                     -17.6
# 2               1.0              2000                     -17.7
# 3               0.9              2000                     -17.6
# 4               2.3              2000                     -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)  is_Winter  is_Spring  \
# 0                      0.0           0.0            0.0       True      False
# 1                      0.0           0.0            0.0       True      False
# 2                      0.0           0.0            0.0       True      False
# 3                      0.0           0.0            0.0       True      False
# 4                      0.0           0.0            0.0       True      False
#
#    is_Summer  is_Autumn  is_Holiday  is_Functioning_day
# 0      False      False       False                True
# 1      False      False       False                True
# 2      False      False       False                True
# 3      False      False       False                True
# 4      False      False       False                True

# %%
# A date has day 'd', month 'm' and year 'y'

class Date:
    def __init__(self, date):
        self.d = int(date[:2])
        self.m = int(date[3:5])
        self.y = int(date[6:])-1900

# To store number of days in all months from January to Dec.

monthDays = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]
 
# This function counts number of leap years since 1900.

def countLeapYears(date):

    years = date.y
 
    # Check if the current year needs to be considered
    # for the count of leap years or not
    if (date.m <= 2):
        years -= 1

    # An year is a leap year if it is a multiple of 4.
    # OR multiple of 400 AND not a multiple of 100.
    return int(years / 4) - int(years / 100) + int((years+300) / 400)

# This function returns number of days passed since 01/01/1900

def Date_to_int(date):
 
    # COUNT TOTAL NUMBER OF DAYS passed since 01/01/1900
    # initialize count using years and day
    days = date.y * 365 + date.d
 
    # Add days for months in given date
    for i in range(0, date.m - 1):
        days += monthDays[i]

    # Since every leap year is of 366 days,
    # Add a day for every leap year
    days += countLeapYears(date)

    return days-1

def weekday(date):
    
    # The days of week rotate on 7-day cycle.
    # 01/01/1900 was a Monday
    Days = {0: "MON",
            1: "TUE",
            2: "WED", 
            3: "THU", 
            4: "FRI",
            5: "SAT",
            6: "SUN"
           }
    return Days[Date_to_int(date)%7]

# %%
# Created 3 empty columns to break down Date Column into usefull data

df["Month"] = np.nan
df["Day"] = np.nan
df["int_date"] = np.nan

for i in range(len(df["Date"])):
    temp_date = Date(df["Date"][i])
    df["Month"][i] = temp_date.m
    df["Day"][i] = weekday(temp_date)
    df["int_date"][i] = Date_to_int(temp_date)

df.head()
# Out:
# /var/folders/xx/rd_rnq597_74rvh871ypgkd00000gn/T/ipykernel_13350/3566899500.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Month"][i] = temp_date.m
# /var/folders/xx/rd_rnq597_74rvh871ypgkd00000gn/T/ipykernel_13350/3566899500.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Day"][i] = weekday(temp_date)
# /var/folders/xx/rd_rnq597_74rvh871ypgkd00000gn/T/ipykernel_13350/3566899500.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["int_date"][i] = Date_to_int(temp_date)
#          Date  Rented Bike Count  Hour  Temperature(C)  Humidity(%)  \
# 0  01/12/2017                254     0            -5.2           37
# 1  01/12/2017                204     1            -5.5           38
# 2  01/12/2017                173     2            -6.0           39
# 3  01/12/2017                107     3            -6.2           40
# 4  01/12/2017                 78     4            -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# 0               2.2              2000                     -17.6
# 1               0.8              2000                     -17.6
# 2               1.0              2000                     -17.7
# 3               0.9              2000                     -17.6
# 4               2.3              2000                     -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)  is_Winter  is_Spring  \
# 0                      0.0           0.0            0.0       True      False
# 1                      0.0           0.0            0.0       True      False
# 2                      0.0           0.0            0.0       True      False
# 3                      0.0           0.0            0.0       True      False
# 4                      0.0           0.0            0.0       True      False
#
#    is_Summer  is_Autumn  is_Holiday  is_Functioning_day  Month  Day  int_date
# 0      False      False       False                True   12.0  FRI   43068.0
# 1      False      False       False                True   12.0  FRI   43068.0
# 2      False      False       False                True   12.0  FRI   43068.0
# 3      False      False       False                True   12.0  FRI   43068.0
# 4      False      False       False                True   12.0  FRI   43068.0

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(50)
titles = list(df.columns)

# To find outliers using box plots

for i in range(1, 11):
    plt.subplot(5, 2, i)
    plt.boxplot(df[df.columns[[i]]])
    plt.title(titles[i])

# %% [markdown]
# The columns with too many outliers are basically crowded with int(0)'s and that has overwelming effect on outlier detection. Thus 0's are droped and coulmns are rechecked for outliers

# %%
col = [[],[],[],[],[]]
col[0] = np.setdiff1d(np.array(df["Rented Bike Count"]), [0])
col[1] = np.setdiff1d(np.array(df["Wind speed (m/s)"]), [0])
col[2] = np.setdiff1d(np.array(df["Solar Radiation (MJ/m2)"]), [0])
col[3] = np.setdiff1d(np.array(df["Rainfall(mm)"]), [0])
col[4] = np.setdiff1d(np.array(df["Snowfall (cm)"]), [0])

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(30)
titles = list(df.columns)

for i in range(1, 6):
    plt.subplot(3, 2, i)
    plt.boxplot(col[i-1])
    if i == 1:
        plt.title("Rented Bike Count")
    elif i == 2:
        plt.title("Wind speed (m/s)")
    else :
         plt.title(titles[i+5])

# %% [markdown]
# Even though the data does have a couple of outliers. they dont seem to be too out of range. Logically thinking, its more statistically possible that these values are not outliers. Thus to ensure the integrety of the data these outliers will be treated as true values.

# %%
df.to_csv("Group_5_data_cleaned.csv", index = False)
df.to_pickle("Group_5_data_cleaned.pkl")
np.savez("Group_5_data_cleaned.npz", df.to_numpy(), index = False)

# %%
df1 = pd.read_csv("Group_5_data_cleaned.csv")
df1.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(C)  Humidity(%)  \
# 0  01/12/2017                254     0            -5.2           37
# 1  01/12/2017                204     1            -5.5           38
# 2  01/12/2017                173     2            -6.0           39
# 3  01/12/2017                107     3            -6.2           40
# 4  01/12/2017                 78     4            -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# 0               2.2              2000                     -17.6
# 1               0.8              2000                     -17.6
# 2               1.0              2000                     -17.7
# 3               0.9              2000                     -17.6
# 4               2.3              2000                     -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)  is_Winter  is_Spring  \
# 0                      0.0           0.0            0.0       True      False
# 1                      0.0           0.0            0.0       True      False
# 2                      0.0           0.0            0.0       True      False
# 3                      0.0           0.0            0.0       True      False
# 4                      0.0           0.0            0.0       True      False
#
#    is_Summer  is_Autumn  is_Holiday  is_Functioning_day  Month  Day  int_date
# 0      False      False       False                True   12.0  FRI   43068.0
# 1      False      False       False                True   12.0  FRI   43068.0
# 2      False      False       False                True   12.0  FRI   43068.0
# 3      False      False       False                True   12.0  FRI   43068.0
# 4      False      False       False                True   12.0  FRI   43068.0

# %%
df2 = pd.read_pickle("Group_5_data_cleaned.pkl")
df2.head()
# Out:
#          Date  Rented Bike Count  Hour  Temperature(C)  Humidity(%)  \
# 0  01/12/2017                254     0            -5.2           37
# 1  01/12/2017                204     1            -5.5           38
# 2  01/12/2017                173     2            -6.0           39
# 3  01/12/2017                107     3            -6.2           40
# 4  01/12/2017                 78     4            -6.0           36
#
#    Wind speed (m/s)  Visibility (10m)  Dew point temperature(C)  \
# 0               2.2              2000                     -17.6
# 1               0.8              2000                     -17.6
# 2               1.0              2000                     -17.7
# 3               0.9              2000                     -17.6
# 4               2.3              2000                     -18.6
#
#    Solar Radiation (MJ/m2)  Rainfall(mm)  Snowfall (cm)  is_Winter  is_Spring  \
# 0                      0.0           0.0            0.0       True      False
# 1                      0.0           0.0            0.0       True      False
# 2                      0.0           0.0            0.0       True      False
# 3                      0.0           0.0            0.0       True      False
# 4                      0.0           0.0            0.0       True      False
#
#    is_Summer  is_Autumn  is_Holiday  is_Functioning_day  Month  Day  int_date
# 0      False      False       False                True   12.0  FRI   43068.0
# 1      False      False       False                True   12.0  FRI   43068.0
# 2      False      False       False                True   12.0  FRI   43068.0
# 3      False      False       False                True   12.0  FRI   43068.0
# 4      False      False       False                True   12.0  FRI   43068.0
